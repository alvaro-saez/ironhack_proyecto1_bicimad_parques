# %%
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd   # conda install -c conda-forge geopandas
import numpy as np
import requests
import warnings
warnings.filterwarnings('ignore');

import osmnx as ox
import folium

import os
import fuzzywuzzy
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %% [markdown]
# ## p_acquisition

# %%
#importar dataset parques municipales JSON
json_parques =  requests.get("https://datos.madrid.es/egob/catalogo/200761-0-parques-jardines.json").json()["@graph"]
json_parques_df = pd.json_normalize(json_parques)
#json_parques_df
#solo para ver si funciona, voy a utilizar csv

# %%
#importar dataset parques municipales CSV
parques_municipales_df = pd.read_csv("datasets/parques_municipales.csv", sep=';')
parques_municipales_df
# Out:
#            PK                               NOMBRE  \
# 0     6070995            Jardines Gregorio Ordóñez
# 1     6010361     Jardines San Francisco el Grande
# 2     5964519           Jardines de Andrés Saborit
# 3     5896013           Jardines de El Buen Retiro
# 4    10984428           Jardines de Gloria Fuertes
# ..        ...                                  ...
# 198   6028228          Vivero Estufas de El Retiro
# 199   6028009           Vivero de la Casa de Campo
# 200   6028007  Vivero municipal de Migas Calientes
# 201   6126515           Zona verde C/ Fresnedillas
# 202   6007791         Área Forestal de Tres Cantos
#
#                                    DESCRIPCION-ENTIDAD  \
# 0    Jardines en memoria de Gregorio Ordóñez. Este ...
# 1    Este jardín se encuentra en el solar de 4.200 ...
# 2    Jardines situados en la calle Raimundo Fernánd...
# 3    Jardín Histórico Artístico creado en el siglo ...
# 4    Jardín dedicado a la poetisa y escritora de cu...
# ..                                                 ...
# 198  Recinto construido en 1889 para albergar diver...
# 199  La primera noticia documental la tenemos en 18...
# 200  Centro de producción donde se realiza el culti...
# 201  Esta nueva zona verde está situada entre las c...
# 202  El Monte de Tres Cantos se sitúa al este del t...
#
#                                                HORARIO  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Horario del parque    Primavera y verano (de a...
# 4                                                  NaN
# ..                                                 ...
# 198  Invierno de 7 a 23 horas. El acceso al público...
# 199  Invierno de 8 a 15 horas Verano de 7 a 14 hora...
# 200                                   De 8 a 15 horas.
# 201                                                NaN
# 202                                                NaN
#
#                                           EQUIPAMIENTO  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Zonas infantiles Zonas de mayores Circuito Bio...
# 3    Zonas infantiles:  Zona del Pinar (Puerta del ...
# 4                                        Zona infantil
# ..                                                 ...
# 198                                                NaN
# 199                                                NaN
# 200                                                NaN
# 201  Zona de juegos infantiles Área de juegos para ...
# 202                                                NaN
#
#                                             TRANSPORTE  \
# 0    Metro: Núñez de Balboa (líneas 5 y 9) Bus: 1, ...
# 1    Bus: 3, 60 y 148.  Servicio Bicimad, para cons...
# 2    Metro: Nuevos Ministerios (líneas 6, 8 y 10) B...
# 3    Metro: Retiro (línea 2), Príncipe de Vergara (...
# 4    Metro: línea 9 (Colombia) Bus: 16,29,150  Serv...
# ..                                                 ...
# 198  Metro: Atocha (línea 1), Ibiza (línea 9) Bus: ...
# 199  Metro: Príncipe Pío (líneas 6 y 10 y ramal), L...
# 200                                                NaN
# 201                                                NaN
# 202                                                NaN
#
#                                            DESCRIPCION  ACCESIBILIDAD  \
# 0    Conservación: Dirección General de Gestión del...              2
# 1    Conservación:Dirección General de Gestión del ...              2
# 2    Conservación: Dirección General de Gestión del...              2
# 3    Conservación: Dirección General de Gestión del...              2
# 4    Conservación: Dirección General de Gestión del...              2
# ..                                                 ...            ...
# 198  Conservación: Dirección General de Gestión del...              0
# 199  Conservación: Dirección General de Gestión del...              2
# 200  Conservación: Dirección General de Gestión del...              0
# 201  Conservación:Dirección General de Gestión del ...              2
# 202  Conservación: Dirección General de Gestión del...              2
#
#                                            CONTENT-URL  \
# 0    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 1    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 2    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 3    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 4    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# ..                                                 ...
# 198  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 199  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 200  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 201  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 202  http://www.madrid.es/sites/v/index.jsp?vgnextc...
#
#                         NOMBRE-VIA  ...             DISTRITO COORDENADA-X  \
# 0              PRINCIPE DE VERGARA  ...            SALAMANCA     442443.0
# 1        GRAN VIA DE SAN FRANCISCO  ...               CENTRO     439572.0
# 2    RAIMUNDO FERNANDEZ VILLAVERDE  ...             CHAMBERI     440726.0
# 3                    INDEPENDENCIA  ...               RETIRO     441640.0
# 4                    MADRE DE DIOS  ...            CHAMARTIN     442761.0
# ..                             ...  ...                  ...          ...
# 198                    ANGEL CAIDO  ...               RETIRO     442107.0
# 199                           AZUL  ...      MONCLOA-ARAVACA     438182.0
# 200                           M-30  ...      MONCLOA-ARAVACA     437249.0
# 201                   FRESNEDILLAS  ...  FUENCARRAL-EL PARDO     437021.0
# 202                          M-607  ...  FUENCARRAL-EL PARDO     440299.0
#
#      COORDENADA-Y    LATITUD  LONGITUD  \
# 0       4476090.0  40.433462 -3.678595
# 1       4473192.0  40.407143 -3.712167
# 2       4477510.0  40.446133 -3.698970
# 3       4474563.0  40.419641 -3.687934
# 4       4479202.0  40.461518 -3.675118
# ..            ...        ...       ...
# 198     4473478.0  40.409899 -3.682331
# 199     4474613.0  40.419842 -3.728697
# 200     4477453.0  40.445356 -3.739974
# 201     4480996.0  40.477264 -3.743003
# 202     4492636.0  40.582363 -3.705431
#
#                                               TELEFONO FAX  \
# 0                                                  NaN NaN
# 1                                                  NaN NaN
# 2                                                  NaN NaN
# 3    915 744 024 (taquillas embarcadero) / 915 280 ... NaN
# 4                                                  NaN NaN
# ..                                                 ...  ..
# 198                                      91 5 28 09 38 NaN
# 199                      91.526.77.03  o  91.480.19.57 NaN
# 200                                          915490676 NaN
# 201                                                NaN NaN
# 202                                                NaN NaN
#
#                                                  EMAIL  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 198                      viveroestufasretiro@madrid.es
# 199  viverocasacampo@madrid.es  o infocasacampo@mad...
# 200                     viveromigascalientes@madrid.es
# 201                                                NaN
# 202                                                NaN
#
#                                                   TIPO  Unnamed: 30
# 0      /contenido/entidadesYorganismos/ParquesJardines
# 1    /contenido/entidadesYorganismos/ParquesJardine...
# 2      /contenido/entidadesYorganismos/ParquesJardines
# 3    /contenido/entidadesYorganismos/ParquesJardine...
# 4                                                  NaN
# ..                                                 ...          ...
# 198    /contenido/entidadesYorganismos/ParquesJardines
# 199    /contenido/entidadesYorganismos/ParquesJardines
# 200                                                NaN
# 201    /contenido/entidadesYorganismos/ParquesJardines
# 202  /contenido/entidadesYorganismos/ParquesJardine...          NaN
#
# [203 rows x 31 columns]

# %%
#parques_municipales_df.iloc[0,:]

# %%
#importar bicimad
#bicimad_st_df = pd.read_csv("datasets/bicimad_statios_database.csv", sep=',')
#bicimad_st_df

# %%
email = "alvarosaezsanchez@gmail.com"
psw = "Bicimad1%"
def bicimad_api(email,psw):
    auth_url = "https://openapi.emtmadrid.es/v1/mobilitylabs/user/login/"
    json_bicimad =  requests.get(auth_url, headers={"email":email,"password":psw})
    json_bicimad_token= json_bicimad.json()['data'][0]['accessToken']
    bicimad_list_url = "https://openapi.emtmadrid.es/v1/transport/bicimad/stations/"
    json_bicimad_list = requests.get(bicimad_list_url, headers = {"accessToken":json_bicimad_token}).json()
    json_bicimad_df = pd.json_normalize(json_bicimad_list)["data"][0]
    
    def geometry_coordinates_bm(geometry):
        geometry_coordinates = geometry["coordinates"]
        return geometry_coordinates
    
    bicimad_st_df = pd.DataFrame(json_bicimad_df)
    bicimad_st_df["geometry_type"] = "Point"
    bicimad_st_df["geometry_coordinates"] = bicimad_st_df["geometry"].apply(geometry_coordinates_bm)
    
    bicimad_st_df = bicimad_st_df.drop(["geometry"], axis=1)
    
    return bicimad_st_df

# %%
bicimad_st_df = bicimad_api(email,psw)
bicimad_st_df
# Out:
#       id                    name  light number  \
# 0      1        Puerta del Sol A      1     1a
# 1      2        Puerta del Sol B      1     1b
# 2      3             Miguel Moya      1      2
# 3      4      Plaza Conde Suchil      2      3
# 4      5                Malasaña      2      4
# ..   ...                     ...    ...    ...
# 259  265                    INEF      2    257
# 260  266  Ciudad Universitaria 1      0    258
# 261  267  Ciudad Universitaria 2      0    259
# 262  268       Facultad Biología      2    260
# 263  269        Facultad Derecho      2    261
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# 3             Plaza del Conde del Valle de Súchil nº 3         1
# 4                          Calle Manuela Malasaña nº 5         1
# ..                                                 ...       ...
# 259  Avenida Juan de Herrera frente a la calle Paul...         1
# 260  Avenida de la Complutense (Metro Ciudad Univer...         1
# 261  Avenida de la Complutense (Metro Ciudad Univer...         1
# 262          Calle José Antonio Novais frente al nº 12         1
# 263                          Avenida Complutense nº 23         1
#
#      no_available  total_bases  dock_bikes  free_bases  reservations_count  \
# 0               0           30          19           6                   0
# 1               0           30          22           8                   0
# 2               0           24          16           6                   0
# 3               0           18           7           8                   0
# 4               0           24          15           8                   0
# ..            ...          ...         ...         ...                 ...
# 259             0           24           9           7                   0
# 260             0           24           2          22                   0
# 261             0           24           5          13                   0
# 262             0           24           9          11                   0
# 263             0           24           9          13                   0
#
#     geometry_type                     geometry_coordinates
# 0           Point                 [-3.7018341, 40.4172137]
# 1           Point  [-3.701602938060457, 40.41731271011562]
# 2           Point                 [-3.7058415, 40.4205886]
# 3           Point                 [-3.7069171, 40.4302937]
# 4           Point                 [-3.7025875, 40.4285524]
# ..            ...                                      ...
# 259         Point                     [-3.72997, 40.43896]
# 260         Point                     [-3.72699, 40.44375]
# 261         Point                     [-3.72693, 40.44342]
# 262         Point                 [-3.7272945, 40.4483322]
# 263         Point                     [-3.72937, 40.45109]
#
# [264 rows x 13 columns]

# %% [markdown]
# ## p_analysis

# %% [markdown]
# #### completar df parques municipales

# %%
parques_municipales_df["Type of Place"] = "Principales parques y jardines municipales"
#parques_municipales_df

# %% [markdown]
# #### obtener latitud y longitud de bicimad

# %%
def bicimad_geo_long(geo):
    geo_clean = str(geo).replace("[","").replace("]","").split(",")
    longitud = geo_clean[0].strip()
    return longitud

# %%
bicimad_st_df["LONGITUD"] = bicimad_st_df["geometry_coordinates"].apply(bicimad_geo_long)
bicimad_st_df.head()
# Out:
#    id                name  light number  \
# 0   1    Puerta del Sol A      1     1a
# 1   2    Puerta del Sol B      1     1b
# 2   3         Miguel Moya      1      2
# 3   4  Plaza Conde Suchil      2      3
# 4   5            Malasaña      2      4
#
#                                     address  activate  no_available  \
# 0                       Puerta del Sol nº 1         1             0
# 1                       Puerta del Sol nº 1         1             0
# 2                    Calle Miguel Moya nº 1         1             0
# 3  Plaza del Conde del Valle de Súchil nº 3         1             0
# 4               Calle Manuela Malasaña nº 5         1             0
#
#    total_bases  dock_bikes  free_bases  reservations_count geometry_type  \
# 0           30          19           6                   0         Point
# 1           30          22           8                   0         Point
# 2           24          16           6                   0         Point
# 3           18           7           8                   0         Point
# 4           24          15           8                   0         Point
#
#                       geometry_coordinates            LONGITUD
# 0                 [-3.7018341, 40.4172137]          -3.7018341
# 1  [-3.701602938060457, 40.41731271011562]  -3.701602938060457
# 2                 [-3.7058415, 40.4205886]          -3.7058415
# 3                 [-3.7069171, 40.4302937]          -3.7069171
# 4                 [-3.7025875, 40.4285524]          -3.7025875

# %%
def bicimad_geo_lat(geo):
    geo_clean = str(geo).replace("[","").replace("]","").split(",")
    latitud = geo_clean[1].strip()
    return latitud

# %%
bicimad_st_df["LATITUD"] = bicimad_st_df["geometry_coordinates"].apply(bicimad_geo_lat)
bicimad_st_df.head()
# Out:
#    id                name  light number  \
# 0   1    Puerta del Sol A      1     1a
# 1   2    Puerta del Sol B      1     1b
# 2   3         Miguel Moya      1      2
# 3   4  Plaza Conde Suchil      2      3
# 4   5            Malasaña      2      4
#
#                                     address  activate  no_available  \
# 0                       Puerta del Sol nº 1         1             0
# 1                       Puerta del Sol nº 1         1             0
# 2                    Calle Miguel Moya nº 1         1             0
# 3  Plaza del Conde del Valle de Súchil nº 3         1             0
# 4               Calle Manuela Malasaña nº 5         1             0
#
#    total_bases  dock_bikes  free_bases  reservations_count geometry_type  \
# 0           30          19           6                   0         Point
# 1           30          22           8                   0         Point
# 2           24          16           6                   0         Point
# 3           18           7           8                   0         Point
# 4           24          15           8                   0         Point
#
#                       geometry_coordinates            LONGITUD  \
# 0                 [-3.7018341, 40.4172137]          -3.7018341
# 1  [-3.701602938060457, 40.41731271011562]  -3.701602938060457
# 2                 [-3.7058415, 40.4205886]          -3.7058415
# 3                 [-3.7069171, 40.4302937]          -3.7069171
# 4                 [-3.7025875, 40.4285524]          -3.7025875
#
#              LATITUD
# 0         40.4172137
# 1  40.41731271011562
# 2         40.4205886
# 3         40.4302937
# 4         40.4285524

# %% [markdown]
# #### preparar la tabla final

# %% [markdown]
# #### a) tabla place

# %%
final_df_colnames_place = ["Place of interest","Type of place","Place address","Place distrit","Place neighborhood","Place description","Place transport","Place latitude","Place longitude"]
len(final_df_colnames_place)
# Out:
# 9

# %%
final_df_place = parques_municipales_df[["NOMBRE","Type of Place","NOMBRE-VIA","DISTRITO", "BARRIO", "DESCRIPCION-ENTIDAD", "TRANSPORTE","LATITUD","LONGITUD"]]
final_df_place.columns = final_df_colnames_place

# %% [markdown]
# #### mercator place

# %%
def to_mercator2(lat, long):
    # transform latitude/longitude data in degrees to pseudo-mercator coordinates in metres
    c = gpd.GeoSeries([Point(lat, long)], crs=4326)
    c = c.to_crs(3857)
    return c

# %%
final_df_place = final_df_place
final_df_place["mercator place"] = final_df_place.apply(lambda final_df_place: to_mercator2(final_df_place["Place latitude"], final_df_place["Place longitude"]), axis=1)

# %%
# %%time
final_df_place
# Out:
# Wall time: 0 ns
#                        Place of interest  \
# 0              Jardines Gregorio Ordóñez
# 1       Jardines San Francisco el Grande
# 2             Jardines de Andrés Saborit
# 3             Jardines de El Buen Retiro
# 4             Jardines de Gloria Fuertes
# ..                                   ...
# 198          Vivero Estufas de El Retiro
# 199           Vivero de la Casa de Campo
# 200  Vivero municipal de Migas Calientes
# 201           Zona verde C/ Fresnedillas
# 202         Área Forestal de Tres Cantos
#
#                                   Type of place  \
# 0    Principales parques y jardines municipales
# 1    Principales parques y jardines municipales
# 2    Principales parques y jardines municipales
# 3    Principales parques y jardines municipales
# 4    Principales parques y jardines municipales
# ..                                          ...
# 198  Principales parques y jardines municipales
# 199  Principales parques y jardines municipales
# 200  Principales parques y jardines municipales
# 201  Principales parques y jardines municipales
# 202  Principales parques y jardines municipales
#
#                      Place address        Place distrit    Place neighborhood  \
# 0              PRINCIPE DE VERGARA            SALAMANCA                 LISTA
# 1        GRAN VIA DE SAN FRANCISCO               CENTRO               PALACIO
# 2    RAIMUNDO FERNANDEZ VILLAVERDE             CHAMBERI            RIOS ROSAS
# 3                    INDEPENDENCIA               RETIRO         LOS JERONIMOS
# 4                    MADRE DE DIOS            CHAMARTIN          NUEVA ESPAÑA
# ..                             ...                  ...                   ...
# 198                    ANGEL CAIDO               RETIRO         LOS JERONIMOS
# 199                           AZUL      MONCLOA-ARAVACA         CASA DE CAMPO
# 200                           M-30      MONCLOA-ARAVACA  CIUDAD UNIVERSITARIA
# 201                   FRESNEDILLAS  FUENCARRAL-EL PARDO        FUENTELARREINA
# 202                          M-607  FUENCARRAL-EL PARDO              EL PARDO
#
#                                      Place description  \
# 0    Jardines en memoria de Gregorio Ordóñez. Este ...
# 1    Este jardín se encuentra en el solar de 4.200 ...
# 2    Jardines situados en la calle Raimundo Fernánd...
# 3    Jardín Histórico Artístico creado en el siglo ...
# 4    Jardín dedicado a la poetisa y escritora de cu...
# ..                                                 ...
# 198  Recinto construido en 1889 para albergar diver...
# 199  La primera noticia documental la tenemos en 18...
# 200  Centro de producción donde se realiza el culti...
# 201  Esta nueva zona verde está situada entre las c...
# 202  El Monte de Tres Cantos se sitúa al este del t...
#
#                                        Place transport  Place latitude  \
# 0    Metro: Núñez de Balboa (líneas 5 y 9) Bus: 1, ...       40.433462
# 1    Bus: 3, 60 y 148.  Servicio Bicimad, para cons...       40.407143
# 2    Metro: Nuevos Ministerios (líneas 6, 8 y 10) B...       40.446133
# 3    Metro: Retiro (línea 2), Príncipe de Vergara (...       40.419641
# 4    Metro: línea 9 (Colombia) Bus: 16,29,150  Serv...       40.461518
# ..                                                 ...             ...
# 198  Metro: Atocha (línea 1), Ibiza (línea 9) Bus: ...       40.409899
# 199  Metro: Príncipe Pío (líneas 6 y 10 y ramal), L...       40.419842
# 200                                                NaN       40.445356
# 201                                                NaN       40.477264
# 202                                                NaN       40.582363
#
#      Place longitude                                mercator place
# 0          -3.678595  POINT (4501032.386132487 -409780.9987743839)
# 1          -3.712167  POINT (4498102.554322098 -413525.9071853098)
# 2          -3.698970  POINT (4502442.959942039 -412053.7810488821)
# 3          -3.687934  POINT (4499493.840154874 -410822.6776250893)
# 4          -3.675118   POINT (4504155.540151379 -409393.078164072)
# ..               ...                                           ...
# 198        -3.682331  POINT (4498409.408289636 -410197.6442728437)
# 199        -3.728697  POINT (4499516.183398882 -415369.9370911405)
# 200        -3.739974  POINT (4502356.383233474 -416627.9974384935)
# 201        -3.743003  POINT (4505908.402877585 -416965.8212977283)
# 202        -3.705431  POINT (4517607.930659908 -412774.5800167918)
#
# [203 rows x 10 columns]

# %% [markdown]
# #### b) tabla bicimad

# %%
final_df_colnames_bici = ["BiciMAD station","Station location","Station latitude","Station longitude","Station base availability","Station Bikes Availability"]

len(final_df_colnames_bici)
#FUTURE COLUMN = "Distance Between BiciMAD station and Place of interest"
# Out:
# 6

# %%
final_df_bici = bicimad_st_df[["name","address","LATITUD","LONGITUD", "no_available", "dock_bikes"]]
final_df_bici.columns = final_df_colnames_bici
final_df_bici
# Out:
#             BiciMAD station  \
# 0          Puerta del Sol A
# 1          Puerta del Sol B
# 2               Miguel Moya
# 3        Plaza Conde Suchil
# 4                  Malasaña
# ..                      ...
# 259                    INEF
# 260  Ciudad Universitaria 1
# 261  Ciudad Universitaria 2
# 262       Facultad Biología
# 263        Facultad Derecho
#
#                                       Station location   Station latitude  \
# 0                                  Puerta del Sol nº 1         40.4172137
# 1                                  Puerta del Sol nº 1  40.41731271011562
# 2                               Calle Miguel Moya nº 1         40.4205886
# 3             Plaza del Conde del Valle de Súchil nº 3         40.4302937
# 4                          Calle Manuela Malasaña nº 5         40.4285524
# ..                                                 ...                ...
# 259  Avenida Juan de Herrera frente a la calle Paul...           40.43896
# 260  Avenida de la Complutense (Metro Ciudad Univer...           40.44375
# 261  Avenida de la Complutense (Metro Ciudad Univer...           40.44342
# 262          Calle José Antonio Novais frente al nº 12         40.4483322
# 263                          Avenida Complutense nº 23           40.45109
#
#       Station longitude  Station base availability  Station Bikes Availability
# 0            -3.7018341                          0                          19
# 1    -3.701602938060457                          0                          22
# 2            -3.7058415                          0                          16
# 3            -3.7069171                          0                           7
# 4            -3.7025875                          0                          15
# ..                  ...                        ...                         ...
# 259            -3.72997                          0                           9
# 260            -3.72699                          0                           2
# 261            -3.72693                          0                           5
# 262          -3.7272945                          0                           9
# 263            -3.72937                          0                           9
#
# [264 rows x 6 columns]

# %% [markdown]
# #### change availability

# %%
def change_availability(data):
    if data == 0:
        return "disponible"
    elif data == 1:
        return "no disponible"
    else:
        return data

# %%
final_df_bici["Station base availability"] = final_df_bici["Station base availability"].apply(change_availability)

# %% [markdown]
# #### mercator station

# %%
# %%time
final_df_bici = final_df_bici
final_df_bici["Station latitude"] = pd.to_numeric(final_df_bici["Station latitude"])
final_df_bici["Station longitude"] = pd.to_numeric(final_df_bici["Station longitude"])
final_df_bici["mercator station"] = final_df_bici.apply(lambda final_df_bici: to_mercator2(final_df_bici["Station latitude"], final_df_bici["Station longitude"]), axis=1)
# Out:
# Wall time: 18.7 s

# %%
final_df_bici
# Out:
#             BiciMAD station  \
# 0          Puerta del Sol A
# 1          Puerta del Sol B
# 2               Miguel Moya
# 3        Plaza Conde Suchil
# 4                  Malasaña
# ..                      ...
# 259                    INEF
# 260  Ciudad Universitaria 1
# 261  Ciudad Universitaria 2
# 262       Facultad Biología
# 263        Facultad Derecho
#
#                                       Station location  Station latitude  \
# 0                                  Puerta del Sol nº 1         40.417214
# 1                                  Puerta del Sol nº 1         40.417313
# 2                               Calle Miguel Moya nº 1         40.420589
# 3             Plaza del Conde del Valle de Súchil nº 3         40.430294
# 4                          Calle Manuela Malasaña nº 5         40.428552
# ..                                                 ...               ...
# 259  Avenida Juan de Herrera frente a la calle Paul...         40.438960
# 260  Avenida de la Complutense (Metro Ciudad Univer...         40.443750
# 261  Avenida de la Complutense (Metro Ciudad Univer...         40.443420
# 262          Calle José Antonio Novais frente al nº 12         40.448332
# 263                          Avenida Complutense nº 23         40.451090
#
#      Station longitude Station base availability  Station Bikes Availability  \
# 0            -3.701834                disponible                          19
# 1            -3.701603                disponible                          22
# 2            -3.705842                disponible                          16
# 3            -3.706917                disponible                           7
# 4            -3.702587                disponible                          15
# ..                 ...                       ...                         ...
# 259          -3.729970                disponible                           9
# 260          -3.726990                disponible                           2
# 261          -3.726930                disponible                           5
# 262          -3.727295                disponible                           9
# 263          -3.729370                disponible                           9
#
#                                  mercator station
# 0    POINT (4499223.648366921 -412373.2851572837)
# 1     POINT (4499234.670122574 -412347.498528782)
# 2    POINT (4499599.340516399 -412820.3206106317)
# 3    POINT (4500679.707306497 -412940.3068148255)
# 4    POINT (4500485.866677178 -412457.3286497012)
# ..                                            ...
# 259  POINT (4501644.435409558 -415511.9577777162)
# 260  POINT (4502177.655770458 -415179.5220676512)
# 261  POINT (4502140.920338497 -415172.8287427764)
# 262  POINT (4502687.743941171 -415213.4906984274)
# 263   POINT (4502994.74083288 -415445.0243226733)
#
# [264 rows x 7 columns]

# %% [markdown]
# #### c) tabla unificada completa con todas las posibilidades de coordenadas

# %%
# %%time
#another way to
final_df = final_df_place.assign(key=1).merge(final_df_bici.assign(key=1), how='outer', on = 'key')
final_df
# Out:
# Wall time: 53.8 ms
#                   Place of interest  \
# 0         Jardines Gregorio Ordóñez
# 1         Jardines Gregorio Ordóñez
# 2         Jardines Gregorio Ordóñez
# 3         Jardines Gregorio Ordóñez
# 4         Jardines Gregorio Ordóñez
# ...                             ...
# 53587  Área Forestal de Tres Cantos
# 53588  Área Forestal de Tres Cantos
# 53589  Área Forestal de Tres Cantos
# 53590  Área Forestal de Tres Cantos
# 53591  Área Forestal de Tres Cantos
#
#                                     Type of place        Place address  \
# 0      Principales parques y jardines municipales  PRINCIPE DE VERGARA
# 1      Principales parques y jardines municipales  PRINCIPE DE VERGARA
# 2      Principales parques y jardines municipales  PRINCIPE DE VERGARA
# 3      Principales parques y jardines municipales  PRINCIPE DE VERGARA
# 4      Principales parques y jardines municipales  PRINCIPE DE VERGARA
# ...                                           ...                  ...
# 53587  Principales parques y jardines municipales                M-607
# 53588  Principales parques y jardines municipales                M-607
# 53589  Principales parques y jardines municipales                M-607
# 53590  Principales parques y jardines municipales                M-607
# 53591  Principales parques y jardines municipales                M-607
#
#              Place distrit Place neighborhood  \
# 0                SALAMANCA              LISTA
# 1                SALAMANCA              LISTA
# 2                SALAMANCA              LISTA
# 3                SALAMANCA              LISTA
# 4                SALAMANCA              LISTA
# ...                    ...                ...
# 53587  FUENCARRAL-EL PARDO           EL PARDO
# 53588  FUENCARRAL-EL PARDO           EL PARDO
# 53589  FUENCARRAL-EL PARDO           EL PARDO
# 53590  FUENCARRAL-EL PARDO           EL PARDO
# 53591  FUENCARRAL-EL PARDO           EL PARDO
#
#                                        Place description  \
# 0      Jardines en memoria de Gregorio Ordóñez. Este ...
# 1      Jardines en memoria de Gregorio Ordóñez. Este ...
# 2      Jardines en memoria de Gregorio Ordóñez. Este ...
# 3      Jardines en memoria de Gregorio Ordóñez. Este ...
# 4      Jardines en memoria de Gregorio Ordóñez. Este ...
# ...                                                  ...
# 53587  El Monte de Tres Cantos se sitúa al este del t...
# 53588  El Monte de Tres Cantos se sitúa al este del t...
# 53589  El Monte de Tres Cantos se sitúa al este del t...
# 53590  El Monte de Tres Cantos se sitúa al este del t...
# 53591  El Monte de Tres Cantos se sitúa al este del t...
#
#                                          Place transport  Place latitude  \
# 0      Metro: Núñez de Balboa (líneas 5 y 9) Bus: 1, ...       40.433462
# 1      Metro: Núñez de Balboa (líneas 5 y 9) Bus: 1, ...       40.433462
# 2      Metro: Núñez de Balboa (líneas 5 y 9) Bus: 1, ...       40.433462
# 3      Metro: Núñez de Balboa (líneas 5 y 9) Bus: 1, ...       40.433462
# 4      Metro: Núñez de Balboa (líneas 5 y 9) Bus: 1, ...       40.433462
# ...                                                  ...             ...
# 53587                                                NaN       40.582363
# 53588                                                NaN       40.582363
# 53589                                                NaN       40.582363
# 53590                                                NaN       40.582363
# 53591                                                NaN       40.582363
#
#        Place longitude                                mercator place  key  \
# 0            -3.678595  POINT (4501032.386132487 -409780.9987743839)    1
# 1            -3.678595  POINT (4501032.386132487 -409780.9987743839)    1
# 2            -3.678595  POINT (4501032.386132487 -409780.9987743839)    1
# 3            -3.678595  POINT (4501032.386132487 -409780.9987743839)    1
# 4            -3.678595  POINT (4501032.386132487 -409780.9987743839)    1
# ...                ...                                           ...  ...
# 53587        -3.705431  POINT (4517607.930659908 -412774.5800167918)    1
# 53588        -3.705431  POINT (4517607.930659908 -412774.5800167918)    1
# 53589        -3.705431  POINT (4517607.930659908 -412774.5800167918)    1
# 53590        -3.705431  POINT (4517607.930659908 -412774.5800167918)    1
# 53591        -3.705431  POINT (4517607.930659908 -412774.5800167918)    1
#
#               BiciMAD station  \
# 0            Puerta del Sol A
# 1            Puerta del Sol B
# 2                 Miguel Moya
# 3          Plaza Conde Suchil
# 4                    Malasaña
# ...                       ...
# 53587                    INEF
# 53588  Ciudad Universitaria 1
# 53589  Ciudad Universitaria 2
# 53590       Facultad Biología
# 53591        Facultad Derecho
#
#                                         Station location  Station latitude  \
# 0                                    Puerta del Sol nº 1         40.417214
# 1                                    Puerta del Sol nº 1         40.417313
# 2                                 Calle Miguel Moya nº 1         40.420589
# 3               Plaza del Conde del Valle de Súchil nº 3         40.430294
# 4                            Calle Manuela Malasaña nº 5         40.428552
# ...                                                  ...               ...
# 53587  Avenida Juan de Herrera frente a la calle Paul...         40.438960
# 53588  Avenida de la Complutense (Metro Ciudad Univer...         40.443750
# 53589  Avenida de la Complutense (Metro Ciudad Univer...         40.443420
# 53590          Calle José Antonio Novais frente al nº 12         40.448332
# 53591                          Avenida Complutense nº 23         40.451090
#
#        Station longitude Station base availability  \
# 0              -3.701834                disponible
# 1              -3.701603                disponible
# 2              -3.705842                disponible
# 3              -3.706917                disponible
# 4              -3.702587                disponible
# ...                  ...                       ...
# 53587          -3.729970                disponible
# 53588          -3.726990                disponible
# 53589          -3.726930                disponible
# 53590          -3.727295                disponible
# 53591          -3.729370                disponible
#
#        Station Bikes Availability  \
# 0                              19
# 1                              22
# 2                              16
# 3                               7
# 4                              15
# ...                           ...
# 53587                           9
# 53588                           2
# 53589                           5
# 53590                           9
# 53591                           9
#
#                                    mercator station
# 0      POINT (4499223.648366921 -412373.2851572837)
# 1       POINT (4499234.670122574 -412347.498528782)
# 2      POINT (4499599.340516399 -412820.3206106317)
# 3      POINT (4500679.707306497 -412940.3068148255)
# 4      POINT (4500485.866677178 -412457.3286497012)
# ...                                             ...
# 53587  POINT (4501644.435409558 -415511.9577777162)
# 53588  POINT (4502177.655770458 -415179.5220676512)
# 53589  POINT (4502140.920338497 -415172.8287427764)
# 53590  POINT (4502687.743941171 -415213.4906984274)
# 53591   POINT (4502994.74083288 -415445.0243226733)
#
# [53592 rows x 18 columns]

# %%
#classic way with for in
"""
final_df_colnames_total = ["Place of interest","Type of place","Place address","Place distrit","Place neighborhood","Place description","Place transport","Place latitude","Place longitude","mercator place","BiciMAD station","Station location","Station latitude","Station longitude","Station base availability","Station Bikes Availability","mercator station"]

final_df_list =[]
for i in range(len(final_df_place)): #203 filas
        for e in range(len(final_df_bici)): # 264 filas
            #raw_number = i*e #53592 filas
            #final_df.loc[raw_number] = final_df_place.loc[i].append(final_df_bici.loc[e])
            str_individual = final_df_place.loc[i].append(final_df_bici.loc[e])
            list_individual = str_individual.tolist()
            final_df_list.append(list_individual)
            
final_df = pd.DataFrame(final_df_list,columns=final_df_colnames_total)
final_df
"""
# Out:
# '\nfinal_df_colnames_total = ["Place of interest","Type of place","Place address","Place distrit","Place neighborhood","Place description","Place transport","Place latitude","Place longitude","mercator place","BiciMAD station","Station location","Station latitude","Station longitude","Station base availability","Station Bikes Availability","mercator station"]\n\nfinal_df_list =[]\nfor i in range(len(final_df_place)): #203 filas\n        for e in range(len(final_df_bici)): # 264 filas\n            #raw_number = i*e #53592 filas\n            #final_df.loc[raw_number] = final_df_place.loc[i].append(final_df_bici.loc[e])\n            str_individual = final_df_place.loc[i].append(final_df_bici.loc[e])\n            list_individual = str_individual.tolist()\n            final_df_list.append(list_individual)\n            \nfinal_df = pd.DataFrame(final_df_list,columns=final_df_colnames_total)\nfinal_df\n'

# %%
def distance_meters(start,finish):
    # return the distance in metres between to latitude/longitude pair point in degrees (i.e.: 40.392436 / -3.6994487)
    #start = to_mercator2(lat_start, long_start)
    #finish = to_mercator2(lat_finish, long_finish)
    return start.distance(finish)

# %%
# %%time
final_df["Distance Between BiciMAD station and Place of interest"] = final_df.apply(lambda final_df: distance_meters(final_df["mercator place"], final_df["mercator station"]), axis=1)
# Out:
# Wall time: 1.14 s

# %%
final_df
# Out:
#                   Place of interest  \
# 0         Jardines Gregorio Ordóñez
# 1         Jardines Gregorio Ordóñez
# 2         Jardines Gregorio Ordóñez
# 3         Jardines Gregorio Ordóñez
# 4         Jardines Gregorio Ordóñez
# ...                             ...
# 53587  Área Forestal de Tres Cantos
# 53588  Área Forestal de Tres Cantos
# 53589  Área Forestal de Tres Cantos
# 53590  Área Forestal de Tres Cantos
# 53591  Área Forestal de Tres Cantos
#
#                                     Type of place        Place address  \
# 0      Principales parques y jardines municipales  PRINCIPE DE VERGARA
# 1      Principales parques y jardines municipales  PRINCIPE DE VERGARA
# 2      Principales parques y jardines municipales  PRINCIPE DE VERGARA
# 3      Principales parques y jardines municipales  PRINCIPE DE VERGARA
# 4      Principales parques y jardines municipales  PRINCIPE DE VERGARA
# ...                                           ...                  ...
# 53587  Principales parques y jardines municipales                M-607
# 53588  Principales parques y jardines municipales                M-607
# 53589  Principales parques y jardines municipales                M-607
# 53590  Principales parques y jardines municipales                M-607
# 53591  Principales parques y jardines municipales                M-607
#
#              Place distrit Place neighborhood  \
# 0                SALAMANCA              LISTA
# 1                SALAMANCA              LISTA
# 2                SALAMANCA              LISTA
# 3                SALAMANCA              LISTA
# 4                SALAMANCA              LISTA
# ...                    ...                ...
# 53587  FUENCARRAL-EL PARDO           EL PARDO
# 53588  FUENCARRAL-EL PARDO           EL PARDO
# 53589  FUENCARRAL-EL PARDO           EL PARDO
# 53590  FUENCARRAL-EL PARDO           EL PARDO
# 53591  FUENCARRAL-EL PARDO           EL PARDO
#
#                                        Place description  \
# 0      Jardines en memoria de Gregorio Ordóñez. Este ...
# 1      Jardines en memoria de Gregorio Ordóñez. Este ...
# 2      Jardines en memoria de Gregorio Ordóñez. Este ...
# 3      Jardines en memoria de Gregorio Ordóñez. Este ...
# 4      Jardines en memoria de Gregorio Ordóñez. Este ...
# ...                                                  ...
# 53587  El Monte de Tres Cantos se sitúa al este del t...
# 53588  El Monte de Tres Cantos se sitúa al este del t...
# 53589  El Monte de Tres Cantos se sitúa al este del t...
# 53590  El Monte de Tres Cantos se sitúa al este del t...
# 53591  El Monte de Tres Cantos se sitúa al este del t...
#
#                                          Place transport  Place latitude  \
# 0      Metro: Núñez de Balboa (líneas 5 y 9) Bus: 1, ...       40.433462
# 1      Metro: Núñez de Balboa (líneas 5 y 9) Bus: 1, ...       40.433462
# 2      Metro: Núñez de Balboa (líneas 5 y 9) Bus: 1, ...       40.433462
# 3      Metro: Núñez de Balboa (líneas 5 y 9) Bus: 1, ...       40.433462
# 4      Metro: Núñez de Balboa (líneas 5 y 9) Bus: 1, ...       40.433462
# ...                                                  ...             ...
# 53587                                                NaN       40.582363
# 53588                                                NaN       40.582363
# 53589                                                NaN       40.582363
# 53590                                                NaN       40.582363
# 53591                                                NaN       40.582363
#
#        Place longitude                                mercator place  key  \
# 0            -3.678595  POINT (4501032.386132487 -409780.9987743839)    1
# 1            -3.678595  POINT (4501032.386132487 -409780.9987743839)    1
# 2            -3.678595  POINT (4501032.386132487 -409780.9987743839)    1
# 3            -3.678595  POINT (4501032.386132487 -409780.9987743839)    1
# 4            -3.678595  POINT (4501032.386132487 -409780.9987743839)    1
# ...                ...                                           ...  ...
# 53587        -3.705431  POINT (4517607.930659908 -412774.5800167918)    1
# 53588        -3.705431  POINT (4517607.930659908 -412774.5800167918)    1
# 53589        -3.705431  POINT (4517607.930659908 -412774.5800167918)    1
# 53590        -3.705431  POINT (4517607.930659908 -412774.5800167918)    1
# 53591        -3.705431  POINT (4517607.930659908 -412774.5800167918)    1
#
#               BiciMAD station  \
# 0            Puerta del Sol A
# 1            Puerta del Sol B
# 2                 Miguel Moya
# 3          Plaza Conde Suchil
# 4                    Malasaña
# ...                       ...
# 53587                    INEF
# 53588  Ciudad Universitaria 1
# 53589  Ciudad Universitaria 2
# 53590       Facultad Biología
# 53591        Facultad Derecho
#
#                                         Station location  Station latitude  \
# 0                                    Puerta del Sol nº 1         40.417214
# 1                                    Puerta del Sol nº 1         40.417313
# 2                                 Calle Miguel Moya nº 1         40.420589
# 3               Plaza del Conde del Valle de Súchil nº 3         40.430294
# 4                            Calle Manuela Malasaña nº 5         40.428552
# ...                                                  ...               ...
# 53587  Avenida Juan de Herrera frente a la calle Paul...         40.438960
# 53588  Avenida de la Complutense (Metro Ciudad Univer...         40.443750
# 53589  Avenida de la Complutense (Metro Ciudad Univer...         40.443420
# 53590          Calle José Antonio Novais frente al nº 12         40.448332
# 53591                          Avenida Complutense nº 23         40.451090
#
#        Station longitude Station base availability  \
# 0              -3.701834                disponible
# 1              -3.701603                disponible
# 2              -3.705842                disponible
# 3              -3.706917                disponible
# 4              -3.702587                disponible
# ...                  ...                       ...
# 53587          -3.729970                disponible
# 53588          -3.726990                disponible
# 53589          -3.726930                disponible
# 53590          -3.727295                disponible
# 53591          -3.729370                disponible
#
#        Station Bikes Availability  \
# 0                              19
# 1                              22
# 2                              16
# 3                               7
# 4                              15
# ...                           ...
# 53587                           9
# 53588                           2
# 53589                           5
# 53590                           9
# 53591                           9
#
#                                    mercator station  \
# 0      POINT (4499223.648366921 -412373.2851572837)
# 1       POINT (4499234.670122574 -412347.498528782)
# 2      POINT (4499599.340516399 -412820.3206106317)
# 3      POINT (4500679.707306497 -412940.3068148255)
# 4      POINT (4500485.866677178 -412457.3286497012)
# ...                                             ...
# 53587  POINT (4501644.435409558 -415511.9577777162)
# 53588  POINT (4502177.655770458 -415179.5220676512)
# 53589  POINT (4502140.920338497 -415172.8287427764)
# 53590  POINT (4502687.743941171 -415213.4906984274)
# 53591   POINT (4502994.74083288 -415445.0243226733)
#
#        Distance Between BiciMAD station and Place of interest
# 0                                            3160.930400
# 1                                            3133.481106
# 2                                            3360.222755
# 3                                            3178.932155
# 4                                            2731.560930
# ...                                                  ...
# 53587                                       16196.493991
# 53588                                       15616.565866
# 53589                                       15651.837120
# 53590                                       15118.209452
# 53591                                       14855.187300
#
# [53592 rows x 19 columns]

# %%
final_df_full_info_csv_optimizated = final_df.to_csv("datasets/final_df_full_info_optimizated.csv", sep=',')

# %%
total_distance_array_min = final_df.groupby(["Place of interest"])["Distance Between BiciMAD station and Place of interest"].min().tolist()

# %%
"""
total_distance = final_df["Distance Between BiciMAD station and Place of interest"].tolist()

total_distance_array = np.array(total_distance).reshape(len(final_df_bici),len(final_df_place))

total_distance_array_min = []
for i in total_distance_array:
    total_distance_array_min.append(i.min())
total_distance_array_min
"""
# Out:
# '\ntotal_distance = final_df["Distance Between BiciMAD station and Place of interest"].tolist()\n\ntotal_distance_array = np.array(total_distance).reshape(len(final_df_bici),len(final_df_place))\n\ntotal_distance_array_min = []\nfor i in total_distance_array:\n    total_distance_array_min.append(i.min())\ntotal_distance_array_min\n'

# %%
list_min=[]
for i in total_distance_array_min:
    linea_para_df = final_df.loc[final_df["Distance Between BiciMAD station and Place of interest"]==i]
    linea_para_df_list = linea_para_df.values.tolist()[0]
    list_min.append(linea_para_df_list)

# %%
final_df_colnames_total = ["Place of interest","Type of place","Place address","Place distrit","Place neighborhood","Place description","Place transport","Place latitude","Place longitude","mercator place","key","BiciMAD station","Station location","Station latitude","Station longitude","Station base availability","Station Bikes Availability","mercator station"]

final_df_min_distance = pd.DataFrame(list_min, columns=final_df_colnames_total+["Distance Between BiciMAD station and Place of interest"])
final_df_min_distance
# Out:
#                        Place of interest  \
# 0              Jardines Gregorio Ordóñez
# 1       Jardines San Francisco el Grande
# 2             Jardines de Andrés Saborit
# 3             Jardines de El Buen Retiro
# 4             Jardines de Gloria Fuertes
# ..                                   ...
# 198          Vivero Estufas de El Retiro
# 199           Vivero de la Casa de Campo
# 200  Vivero municipal de Migas Calientes
# 201           Zona verde C/ Fresnedillas
# 202         Área Forestal de Tres Cantos
#
#                                   Type of place  \
# 0    Principales parques y jardines municipales
# 1    Principales parques y jardines municipales
# 2    Principales parques y jardines municipales
# 3    Principales parques y jardines municipales
# 4    Principales parques y jardines municipales
# ..                                          ...
# 198  Principales parques y jardines municipales
# 199  Principales parques y jardines municipales
# 200  Principales parques y jardines municipales
# 201  Principales parques y jardines municipales
# 202  Principales parques y jardines municipales
#
#                      Place address        Place distrit    Place neighborhood  \
# 0              PRINCIPE DE VERGARA            SALAMANCA                 LISTA
# 1        GRAN VIA DE SAN FRANCISCO               CENTRO               PALACIO
# 2    RAIMUNDO FERNANDEZ VILLAVERDE             CHAMBERI            RIOS ROSAS
# 3                    INDEPENDENCIA               RETIRO         LOS JERONIMOS
# 4                    MADRE DE DIOS            CHAMARTIN          NUEVA ESPAÑA
# ..                             ...                  ...                   ...
# 198                    ANGEL CAIDO               RETIRO         LOS JERONIMOS
# 199                           AZUL      MONCLOA-ARAVACA         CASA DE CAMPO
# 200                           M-30      MONCLOA-ARAVACA  CIUDAD UNIVERSITARIA
# 201                   FRESNEDILLAS  FUENCARRAL-EL PARDO        FUENTELARREINA
# 202                          M-607  FUENCARRAL-EL PARDO              EL PARDO
#
#                                      Place description  \
# 0    Jardines en memoria de Gregorio Ordóñez. Este ...
# 1    Este jardín se encuentra en el solar de 4.200 ...
# 2    Jardines situados en la calle Raimundo Fernánd...
# 3    Jardín Histórico Artístico creado en el siglo ...
# 4    Jardín dedicado a la poetisa y escritora de cu...
# ..                                                 ...
# 198  Recinto construido en 1889 para albergar diver...
# 199  La primera noticia documental la tenemos en 18...
# 200  Centro de producción donde se realiza el culti...
# 201  Esta nueva zona verde está situada entre las c...
# 202  El Monte de Tres Cantos se sitúa al este del t...
#
#                                        Place transport  Place latitude  \
# 0    Metro: Núñez de Balboa (líneas 5 y 9) Bus: 1, ...       40.433462
# 1    Bus: 3, 60 y 148.  Servicio Bicimad, para cons...       40.407143
# 2    Metro: Nuevos Ministerios (líneas 6, 8 y 10) B...       40.446133
# 3    Metro: Retiro (línea 2), Príncipe de Vergara (...       40.419641
# 4    Metro: línea 9 (Colombia) Bus: 16,29,150  Serv...       40.461518
# ..                                                 ...             ...
# 198  Metro: Atocha (línea 1), Ibiza (línea 9) Bus: ...       40.409899
# 199  Metro: Príncipe Pío (líneas 6 y 10 y ramal), L...       40.419842
# 200                                                NaN       40.445356
# 201                                                NaN       40.477264
# 202                                                NaN       40.582363
#
#      Place longitude                                mercator place  key  \
# 0          -3.678595  POINT (4501032.386132487 -409780.9987743839)    1
# 1          -3.712167  POINT (4498102.554322098 -413525.9071853098)    1
# 2          -3.698970  POINT (4502442.959942039 -412053.7810488821)    1
# 3          -3.687934  POINT (4499493.840154874 -410822.6776250893)    1
# 4          -3.675118   POINT (4504155.540151379 -409393.078164072)    1
# ..               ...                                           ...  ...
# 198        -3.682331  POINT (4498409.408289636 -410197.6442728437)    1
# 199        -3.728697  POINT (4499516.183398882 -415369.9370911405)    1
# 200        -3.739974  POINT (4502356.383233474 -416627.9974384935)    1
# 201        -3.743003  POINT (4505908.402877585 -416965.8212977283)    1
# 202        -3.705431  POINT (4517607.930659908 -412774.5800167918)    1
#
#                BiciMAD station  \
# 0             Diego de León 52
# 1             Puerta de Toledo
# 2           Raimundo Fernández
# 3    Plaza de la Independencia
# 4                      Pío XII
# ..                         ...
# 198            Menéndez Pelayo
# 199           Puerta del Ángel
# 200                       INEF
# 201           Facultad Derecho
# 202                 Pedro Rico
#
#                                       Station location  Station latitude  \
# 0                            Calle Diego de León nº 52         40.434597
# 1                 Glorieta de la Puerta de Toledo nº 1         40.407036
# 2            Calle Raimundo Fernández Villaverde nº 33         40.447125
# 3                       Plaza de la Independencia nº 6         40.419752
# 4                                 Avenida Pío XII nº 3         40.460410
# ..                                                 ...               ...
# 198  Avenida de Menéndez Pelayo con calle Poeta Est...         40.408280
# 199                        Plaza Puerta del Ángel nº 4         40.413764
# 200  Avenida Juan de Herrera frente a la calle Paul...         40.438960
# 201                          Avenida Complutense nº 23         40.451090
# 202                              Calle Pedro Rico nº 4         40.481086
#
#      Station longitude Station base availability  Station Bikes Availability  \
# 0            -3.678492                disponible                           5
# 1            -3.711051                disponible                          19
# 2            -3.700167                disponible                           3
# 3            -3.688398                disponible                          13
# 4            -3.677120                disponible                           5
# ..                 ...                       ...                         ...
# 198          -3.678484                disponible                          10
# 199          -3.728318                disponible                          10
# 200          -3.729970                disponible                           9
# 201          -3.729370                disponible                           9
# 202          -3.688463                disponible                           2
#
#                                  mercator station  \
# 0    POINT (4501158.781867075 -409769.4558894613)
# 1    POINT (4498090.649721576 -413401.4898074972)
# 2    POINT (4502553.359051885 -412187.3054398999)
# 3     POINT (4499506.210630401 -410874.469478817)
# 4    POINT (4504032.238487074 -409616.4103570179)
# ..                                            ...
# 198  POINT (4498229.209091766 -409768.5411851413)
# 199  POINT (4498839.629519532 -415327.6677751078)
# 200  POINT (4501644.435409558 -415511.9577777162)
# 201   POINT (4502994.74083288 -415445.0243226733)
# 202  POINT (4506333.880278716 -410881.7202647889)
#
#      Distance Between BiciMAD station and Place of interest
# 0                                           126.921708
# 1                                           124.985613
# 2                                           173.253359
# 3                                            53.248707
# 4                                           255.108935
# ..                                                 ...
# 198                                         465.404352
# 199                                         677.873031
# 200                                        1323.787834
# 201                                        3286.677646
# 202                                       11431.847184
#
# [203 rows x 19 columns]

# %%
#comprobacion
min(final_df.iloc[0:264,:]["Distance Between BiciMAD station and Place of interest"])
# Out:
# 126.92170781350367

# %%
final_df_min_distance_csv_optimizated = final_df_min_distance.to_csv("datasets/final_df_min_distance_optimizated.csv", sep=',')

# %% [markdown]
# ## extra

# %%
#https://www.google.com/maps/dir/Prta+del+Sol/Vivero+Municipal+de+la+Casa+de+Campo

# %%
def place_maps_func(data):
    place_maps = "+".join(data.split(" "))
    return place_maps

# %%
def g_maps_func(place_maps, bici_maps):
    g_maps = "https://www.google.com/maps/dir/" + str(place_maps) + "/" + str(bici_maps)
    return g_maps

# %%
final_df_min_distance["place_maps"] = final_df_min_distance["Place of interest"].apply(place_maps_func)
final_df_min_distance["bici_maps"] = final_df_min_distance["Station location"].apply(place_maps_func)
final_df_min_distance["g_maps"] = final_df_min_distance.apply(lambda final_df_min_distance: g_maps_func(final_df_min_distance["place_maps"], final_df_min_distance["bici_maps"]), axis=1)

final_df_min_distance
# Out:
#                        Place of interest  \
# 0              Jardines Gregorio Ordóñez
# 1       Jardines San Francisco el Grande
# 2             Jardines de Andrés Saborit
# 3             Jardines de El Buen Retiro
# 4             Jardines de Gloria Fuertes
# ..                                   ...
# 198          Vivero Estufas de El Retiro
# 199           Vivero de la Casa de Campo
# 200  Vivero municipal de Migas Calientes
# 201           Zona verde C/ Fresnedillas
# 202         Área Forestal de Tres Cantos
#
#                                   Type of place  \
# 0    Principales parques y jardines municipales
# 1    Principales parques y jardines municipales
# 2    Principales parques y jardines municipales
# 3    Principales parques y jardines municipales
# 4    Principales parques y jardines municipales
# ..                                          ...
# 198  Principales parques y jardines municipales
# 199  Principales parques y jardines municipales
# 200  Principales parques y jardines municipales
# 201  Principales parques y jardines municipales
# 202  Principales parques y jardines municipales
#
#                      Place address        Place distrit    Place neighborhood  \
# 0              PRINCIPE DE VERGARA            SALAMANCA                 LISTA
# 1        GRAN VIA DE SAN FRANCISCO               CENTRO               PALACIO
# 2    RAIMUNDO FERNANDEZ VILLAVERDE             CHAMBERI            RIOS ROSAS
# 3                    INDEPENDENCIA               RETIRO         LOS JERONIMOS
# 4                    MADRE DE DIOS            CHAMARTIN          NUEVA ESPAÑA
# ..                             ...                  ...                   ...
# 198                    ANGEL CAIDO               RETIRO         LOS JERONIMOS
# 199                           AZUL      MONCLOA-ARAVACA         CASA DE CAMPO
# 200                           M-30      MONCLOA-ARAVACA  CIUDAD UNIVERSITARIA
# 201                   FRESNEDILLAS  FUENCARRAL-EL PARDO        FUENTELARREINA
# 202                          M-607  FUENCARRAL-EL PARDO              EL PARDO
#
#                                      Place description  \
# 0    Jardines en memoria de Gregorio Ordóñez. Este ...
# 1    Este jardín se encuentra en el solar de 4.200 ...
# 2    Jardines situados en la calle Raimundo Fernánd...
# 3    Jardín Histórico Artístico creado en el siglo ...
# 4    Jardín dedicado a la poetisa y escritora de cu...
# ..                                                 ...
# 198  Recinto construido en 1889 para albergar diver...
# 199  La primera noticia documental la tenemos en 18...
# 200  Centro de producción donde se realiza el culti...
# 201  Esta nueva zona verde está situada entre las c...
# 202  El Monte de Tres Cantos se sitúa al este del t...
#
#                                        Place transport  Place latitude  \
# 0    Metro: Núñez de Balboa (líneas 5 y 9) Bus: 1, ...       40.433462
# 1    Bus: 3, 60 y 148.  Servicio Bicimad, para cons...       40.407143
# 2    Metro: Nuevos Ministerios (líneas 6, 8 y 10) B...       40.446133
# 3    Metro: Retiro (línea 2), Príncipe de Vergara (...       40.419641
# 4    Metro: línea 9 (Colombia) Bus: 16,29,150  Serv...       40.461518
# ..                                                 ...             ...
# 198  Metro: Atocha (línea 1), Ibiza (línea 9) Bus: ...       40.409899
# 199  Metro: Príncipe Pío (líneas 6 y 10 y ramal), L...       40.419842
# 200                                                NaN       40.445356
# 201                                                NaN       40.477264
# 202                                                NaN       40.582363
#
#      Place longitude                                mercator place  ...  \
# 0          -3.678595  POINT (4501032.386132487 -409780.9987743839)  ...
# 1          -3.712167  POINT (4498102.554322098 -413525.9071853098)  ...
# 2          -3.698970  POINT (4502442.959942039 -412053.7810488821)  ...
# 3          -3.687934  POINT (4499493.840154874 -410822.6776250893)  ...
# 4          -3.675118   POINT (4504155.540151379 -409393.078164072)  ...
# ..               ...                                           ...  ...
# 198        -3.682331  POINT (4498409.408289636 -410197.6442728437)  ...
# 199        -3.728697  POINT (4499516.183398882 -415369.9370911405)  ...
# 200        -3.739974  POINT (4502356.383233474 -416627.9974384935)  ...
# 201        -3.743003  POINT (4505908.402877585 -416965.8212977283)  ...
# 202        -3.705431  POINT (4517607.930659908 -412774.5800167918)  ...
#
#                                       Station location Station latitude  \
# 0                            Calle Diego de León nº 52        40.434597
# 1                 Glorieta de la Puerta de Toledo nº 1        40.407036
# 2            Calle Raimundo Fernández Villaverde nº 33        40.447125
# 3                       Plaza de la Independencia nº 6        40.419752
# 4                                 Avenida Pío XII nº 3        40.460410
# ..                                                 ...              ...
# 198  Avenida de Menéndez Pelayo con calle Poeta Est...        40.408280
# 199                        Plaza Puerta del Ángel nº 4        40.413764
# 200  Avenida Juan de Herrera frente a la calle Paul...        40.438960
# 201                          Avenida Complutense nº 23        40.451090
# 202                              Calle Pedro Rico nº 4        40.481086
#
#     Station longitude  Station base availability  Station Bikes Availability  \
# 0           -3.678492                 disponible                           5
# 1           -3.711051                 disponible                          19
# 2           -3.700167                 disponible                           3
# 3           -3.688398                 disponible                          13
# 4           -3.677120                 disponible                           5
# ..                ...                        ...                         ...
# 198         -3.678484                 disponible                          10
# 199         -3.728318                 disponible                          10
# 200         -3.729970                 disponible                           9
# 201         -3.729370                 disponible                           9
# 202         -3.688463                 disponible                           2
#
#                                  mercator station  \
# 0    POINT (4501158.781867075 -409769.4558894613)
# 1    POINT (4498090.649721576 -413401.4898074972)
# 2    POINT (4502553.359051885 -412187.3054398999)
# 3     POINT (4499506.210630401 -410874.469478817)
# 4    POINT (4504032.238487074 -409616.4103570179)
# ..                                            ...
# 198  POINT (4498229.209091766 -409768.5411851413)
# 199  POINT (4498839.629519532 -415327.6677751078)
# 200  POINT (4501644.435409558 -415511.9577777162)
# 201   POINT (4502994.74083288 -415445.0243226733)
# 202  POINT (4506333.880278716 -410881.7202647889)
#
#      Distance Between BiciMAD station and Place of interest  \
# 0                                           126.921708
# 1                                           124.985613
# 2                                           173.253359
# 3                                            53.248707
# 4                                           255.108935
# ..                                                 ...
# 198                                         465.404352
# 199                                         677.873031
# 200                                        1323.787834
# 201                                        3286.677646
# 202                                       11431.847184
#
#                               place_maps  \
# 0              Jardines+Gregorio+Ordóñez
# 1       Jardines+San+Francisco+el+Grande
# 2             Jardines+de+Andrés+Saborit
# 3             Jardines+de+El+Buen+Retiro
# 4             Jardines+de+Gloria+Fuertes
# ..                                   ...
# 198          Vivero+Estufas+de+El+Retiro
# 199           Vivero+de+la+Casa+de+Campo
# 200  Vivero+municipal+de+Migas+Calientes
# 201           Zona+verde+C/+Fresnedillas
# 202         Área+Forestal+de+Tres+Cantos
#
#                                              bici_maps  \
# 0                            Calle+Diego+de+León+nº+52
# 1                 Glorieta+de+la+Puerta+de+Toledo+nº+1
# 2            Calle+Raimundo+Fernández+Villaverde+nº+33
# 3                       Plaza+de+la+Independencia+nº+6
# 4                                 Avenida+Pío+XII+nº+3
# ..                                                 ...
# 198  Avenida+de+Menéndez+Pelayo+con+calle+Poeta+Est...
# 199                        Plaza+Puerta+del+Ángel+nº+4
# 200  Avenida+Juan+de+Herrera+frente+a+la+calle+Paul...
# 201                          Avenida+Complutense+nº+23
# 202                              Calle+Pedro+Rico+nº+4
#
#                                                 g_maps
# 0    https://www.google.com/maps/dir/Jardines+Grego...
# 1    https://www.google.com/maps/dir/Jardines+San+F...
# 2    https://www.google.com/maps/dir/Jardines+de+An...
# 3    https://www.google.com/maps/dir/Jardines+de+El...
# 4    https://www.google.com/maps/dir/Jardines+de+Gl...
# ..                                                 ...
# 198  https://www.google.com/maps/dir/Vivero+Estufas...
# 199  https://www.google.com/maps/dir/Vivero+de+la+C...
# 200  https://www.google.com/maps/dir/Vivero+municip...
# 201  https://www.google.com/maps/dir/Zona+verde+C/+...
# 202  https://www.google.com/maps/dir/Área+Forestal+...
#
# [203 rows x 22 columns]

# %% [markdown]
# ### open street maps

# %%
open_street_df = pd.DataFrame(final_df_min_distance["mercator place"])
open_street_df
# Out:
#                                    mercator place
# 0    POINT (4501032.386132487 -409780.9987743839)
# 1    POINT (4498102.554322098 -413525.9071853098)
# 2    POINT (4502442.959942039 -412053.7810488821)
# 3    POINT (4499493.840154874 -410822.6776250893)
# 4     POINT (4504155.540151379 -409393.078164072)
# ..                                            ...
# 198  POINT (4498409.408289636 -410197.6442728437)
# 199  POINT (4499516.183398882 -415369.9370911405)
# 200  POINT (4502356.383233474 -416627.9974384935)
# 201  POINT (4505908.402877585 -416965.8212977283)
# 202  POINT (4517607.930659908 -412774.5800167918)
#
# [203 rows x 1 columns]

# %%
def lat_long_open_street0(geo):
    open_geo = str(geo).replace("POINT (","").replace(")","").split(" ")
    open_point_0 = open_geo[0].strip()
    return open_point_0

# %%
def lat_long_open_street1(geo):
    open_geo = str(geo).replace("POINT (","").replace(")","").split(" ")
    open_point_1 = open_geo[1].strip()
    return open_point_1

# %%
open_street_df["open_0"] = open_street_df["mercator place"].apply(lat_long_open_street0)
open_street_df["open_1"] = open_street_df["mercator place"].apply(lat_long_open_street1)
open_street_df["Place latitude"] = final_df_min_distance["Place latitude"]
open_street_df["Place longitude"] = final_df_min_distance["Place longitude"]

open_street_df
# Out:
#                                    mercator place             open_0  \
# 0    POINT (4501032.386132487 -409780.9987743839)  4501032.386132487
# 1    POINT (4498102.554322098 -413525.9071853098)  4498102.554322098
# 2    POINT (4502442.959942039 -412053.7810488821)  4502442.959942039
# 3    POINT (4499493.840154874 -410822.6776250893)  4499493.840154874
# 4     POINT (4504155.540151379 -409393.078164072)  4504155.540151379
# ..                                            ...                ...
# 198  POINT (4498409.408289636 -410197.6442728437)  4498409.408289636
# 199  POINT (4499516.183398882 -415369.9370911405)  4499516.183398882
# 200  POINT (4502356.383233474 -416627.9974384935)  4502356.383233474
# 201  POINT (4505908.402877585 -416965.8212977283)  4505908.402877585
# 202  POINT (4517607.930659908 -412774.5800167918)  4517607.930659908
#
#                  open_1  Place latitude  Place longitude
# 0    -409780.9987743839       40.433462        -3.678595
# 1    -413525.9071853098       40.407143        -3.712167
# 2    -412053.7810488821       40.446133        -3.698970
# 3    -410822.6776250893       40.419641        -3.687934
# 4     -409393.078164072       40.461518        -3.675118
# ..                  ...             ...              ...
# 198  -410197.6442728437       40.409899        -3.682331
# 199  -415369.9370911405       40.419842        -3.728697
# 200  -416627.9974384935       40.445356        -3.739974
# 201  -416965.8212977283       40.477264        -3.743003
# 202  -412774.5800167918       40.582363        -3.705431
#
# [203 rows x 5 columns]

# %%
m = folium.Map([40.433462, -3.678595], zoom_start=12)
locs = zip(open_street_df["Place latitude"].tolist(), open_street_df["Place longitude"].tolist())
for location in locs:
    #print(location)
    if "nan" not in str(location):
        folium.CircleMarker(location=location).add_to(m)
        m.save('open_street_df.html')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_11f717712e644834b9a64fc420b470a9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_11f717712e644834b9a64fc420b470a9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_11f717712e644834b9a64fc420b470a9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_11f717712e644834b9a64fc420b470a9%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.433462%2C%20-3.678595%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
def fw_ratio(x):
    fw1 = x
    fw2 = user_imput
    ratio = fuzz.ratio(user_imput.lower().strip(), x.lower().strip())
    return ratio

# %%
user_imput = " vichwero estufas de El   Reero"

# %%
final_df_min_distance["place_sim_ratio"] = final_df_min_distance["Place of interest"].apply(fw_ratio)

# %%
final_df_min_distance
# Out:
#                        Place of interest  \
# 0              Jardines Gregorio Ordóñez
# 1       Jardines San Francisco el Grande
# 2             Jardines de Andrés Saborit
# 3             Jardines de El Buen Retiro
# 4             Jardines de Gloria Fuertes
# ..                                   ...
# 198          Vivero Estufas de El Retiro
# 199           Vivero de la Casa de Campo
# 200  Vivero municipal de Migas Calientes
# 201           Zona verde C/ Fresnedillas
# 202         Área Forestal de Tres Cantos
#
#                                   Type of place  \
# 0    Principales parques y jardines municipales
# 1    Principales parques y jardines municipales
# 2    Principales parques y jardines municipales
# 3    Principales parques y jardines municipales
# 4    Principales parques y jardines municipales
# ..                                          ...
# 198  Principales parques y jardines municipales
# 199  Principales parques y jardines municipales
# 200  Principales parques y jardines municipales
# 201  Principales parques y jardines municipales
# 202  Principales parques y jardines municipales
#
#                      Place address        Place distrit    Place neighborhood  \
# 0              PRINCIPE DE VERGARA            SALAMANCA                 LISTA
# 1        GRAN VIA DE SAN FRANCISCO               CENTRO               PALACIO
# 2    RAIMUNDO FERNANDEZ VILLAVERDE             CHAMBERI            RIOS ROSAS
# 3                    INDEPENDENCIA               RETIRO         LOS JERONIMOS
# 4                    MADRE DE DIOS            CHAMARTIN          NUEVA ESPAÑA
# ..                             ...                  ...                   ...
# 198                    ANGEL CAIDO               RETIRO         LOS JERONIMOS
# 199                           AZUL      MONCLOA-ARAVACA         CASA DE CAMPO
# 200                           M-30      MONCLOA-ARAVACA  CIUDAD UNIVERSITARIA
# 201                   FRESNEDILLAS  FUENCARRAL-EL PARDO        FUENTELARREINA
# 202                          M-607  FUENCARRAL-EL PARDO              EL PARDO
#
#                                      Place description  \
# 0    Jardines en memoria de Gregorio Ordóñez. Este ...
# 1    Este jardín se encuentra en el solar de 4.200 ...
# 2    Jardines situados en la calle Raimundo Fernánd...
# 3    Jardín Histórico Artístico creado en el siglo ...
# 4    Jardín dedicado a la poetisa y escritora de cu...
# ..                                                 ...
# 198  Recinto construido en 1889 para albergar diver...
# 199  La primera noticia documental la tenemos en 18...
# 200  Centro de producción donde se realiza el culti...
# 201  Esta nueva zona verde está situada entre las c...
# 202  El Monte de Tres Cantos se sitúa al este del t...
#
#                                        Place transport  Place latitude  \
# 0    Metro: Núñez de Balboa (líneas 5 y 9) Bus: 1, ...       40.433462
# 1    Bus: 3, 60 y 148.  Servicio Bicimad, para cons...       40.407143
# 2    Metro: Nuevos Ministerios (líneas 6, 8 y 10) B...       40.446133
# 3    Metro: Retiro (línea 2), Príncipe de Vergara (...       40.419641
# 4    Metro: línea 9 (Colombia) Bus: 16,29,150  Serv...       40.461518
# ..                                                 ...             ...
# 198  Metro: Atocha (línea 1), Ibiza (línea 9) Bus: ...       40.409899
# 199  Metro: Príncipe Pío (líneas 6 y 10 y ramal), L...       40.419842
# 200                                                NaN       40.445356
# 201                                                NaN       40.477264
# 202                                                NaN       40.582363
#
#      Place longitude                                mercator place  ...  \
# 0          -3.678595  POINT (4501032.386132487 -409780.9987743839)  ...
# 1          -3.712167  POINT (4498102.554322098 -413525.9071853098)  ...
# 2          -3.698970  POINT (4502442.959942039 -412053.7810488821)  ...
# 3          -3.687934  POINT (4499493.840154874 -410822.6776250893)  ...
# 4          -3.675118   POINT (4504155.540151379 -409393.078164072)  ...
# ..               ...                                           ...  ...
# 198        -3.682331  POINT (4498409.408289636 -410197.6442728437)  ...
# 199        -3.728697  POINT (4499516.183398882 -415369.9370911405)  ...
# 200        -3.739974  POINT (4502356.383233474 -416627.9974384935)  ...
# 201        -3.743003  POINT (4505908.402877585 -416965.8212977283)  ...
# 202        -3.705431  POINT (4517607.930659908 -412774.5800167918)  ...
#
#      Station latitude Station longitude Station base availability  \
# 0           40.434597         -3.678492                disponible
# 1           40.407036         -3.711051                disponible
# 2           40.447125         -3.700167                disponible
# 3           40.419752         -3.688398                disponible
# 4           40.460410         -3.677120                disponible
# ..                ...               ...                       ...
# 198         40.408280         -3.678484                disponible
# 199         40.413764         -3.728318                disponible
# 200         40.438960         -3.729970                disponible
# 201         40.451090         -3.729370                disponible
# 202         40.481086         -3.688463                disponible
#
#      Station Bikes Availability                              mercator station  \
# 0                             5  POINT (4501158.781867075 -409769.4558894613)
# 1                            19  POINT (4498090.649721576 -413401.4898074972)
# 2                             3  POINT (4502553.359051885 -412187.3054398999)
# 3                            13   POINT (4499506.210630401 -410874.469478817)
# 4                             5  POINT (4504032.238487074 -409616.4103570179)
# ..                          ...                                           ...
# 198                          10  POINT (4498229.209091766 -409768.5411851413)
# 199                          10  POINT (4498839.629519532 -415327.6677751078)
# 200                           9  POINT (4501644.435409558 -415511.9577777162)
# 201                           9   POINT (4502994.74083288 -415445.0243226733)
# 202                           2  POINT (4506333.880278716 -410881.7202647889)
#
#     Distance Between BiciMAD station and Place of interest  \
# 0                                           126.921708
# 1                                           124.985613
# 2                                           173.253359
# 3                                            53.248707
# 4                                           255.108935
# ..                                                 ...
# 198                                         465.404352
# 199                                         677.873031
# 200                                        1323.787834
# 201                                        3286.677646
# 202                                       11431.847184
#
#                               place_maps  \
# 0              Jardines+Gregorio+Ordóñez
# 1       Jardines+San+Francisco+el+Grande
# 2             Jardines+de+Andrés+Saborit
# 3             Jardines+de+El+Buen+Retiro
# 4             Jardines+de+Gloria+Fuertes
# ..                                   ...
# 198          Vivero+Estufas+de+El+Retiro
# 199           Vivero+de+la+Casa+de+Campo
# 200  Vivero+municipal+de+Migas+Calientes
# 201           Zona+verde+C/+Fresnedillas
# 202         Área+Forestal+de+Tres+Cantos
#
#                                              bici_maps  \
# 0                            Calle+Diego+de+León+nº+52
# 1                 Glorieta+de+la+Puerta+de+Toledo+nº+1
# 2            Calle+Raimundo+Fernández+Villaverde+nº+33
# 3                       Plaza+de+la+Independencia+nº+6
# 4                                 Avenida+Pío+XII+nº+3
# ..                                                 ...
# 198  Avenida+de+Menéndez+Pelayo+con+calle+Poeta+Est...
# 199                        Plaza+Puerta+del+Ángel+nº+4
# 200  Avenida+Juan+de+Herrera+frente+a+la+calle+Paul...
# 201                          Avenida+Complutense+nº+23
# 202                              Calle+Pedro+Rico+nº+4
#
#                                                 g_maps place_sim_ratio
# 0    https://www.google.com/maps/dir/Jardines+Grego...              29
# 1    https://www.google.com/maps/dir/Jardines+San+F...              42
# 2    https://www.google.com/maps/dir/Jardines+de+An...              32
# 3    https://www.google.com/maps/dir/Jardines+de+El...              54
# 4    https://www.google.com/maps/dir/Jardines+de+Gl...              39
# ..                                                 ...             ...
# 198  https://www.google.com/maps/dir/Vivero+Estufas...              84
# 199  https://www.google.com/maps/dir/Vivero+de+la+C...              50
# 200  https://www.google.com/maps/dir/Vivero+municip...              46
# 201  https://www.google.com/maps/dir/Zona+verde+C/+...              36
# 202  https://www.google.com/maps/dir/Área+Forestal+...              45
#
# [203 rows x 23 columns]

# %%
pd.set_option('display.max_rows', 500)
max_ratio_test = final_df_min_distance["place_sim_ratio"].max()
max_ratio_test
# Out:
# 84

# %%
#que nos devuelva en función de el maximo el nombre del parque que debería ser y su bici

# %%
place_ratio = final_df_min_distance.loc[(final_df_min_distance[("place_sim_ratio")]==max_ratio_test)]["Place of interest"].tolist()[0]

# %%
place_ratio
# Out:
# 'Vivero Estufas de El Retiro'
